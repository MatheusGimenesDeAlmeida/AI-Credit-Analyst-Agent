# %% [markdown]
# # Teste 3 Market Sizing

# %% [markdown]
# ### Utilizando LLM para ler um demonstrativo financeiro de uma empresa e identificar o PDD

# %%
import os
import glob
from dotenv import load_dotenv

# Leitura e parsing de PDF
from unstructured.partition.pdf import partition_pdf

# %%
import logging

arquivo_pdf = "demonstrativos/BMG.pdf"
logging.getLogger("pdfminer").setLevel(logging.ERROR) # silencia logs do pdfminer (usado pelo unstructured)
elementos = partition_pdf(filename=arquivo_pdf, languages=["por"])

for e in elementos[:250]:
    print(e.category, "->", str(e)[:200])
# Out:
# Title -> BMGB B3 LISTED N1
# NarrativeText -> Demonstrações financeiras individuais e consolidadas em 30 de junho de 2025 e relatório do auditor independente sobre as demonstrações financeiras
# Footer -> Este documento contém informação RESTRITA. Seu conteúdo é restrito às partes interessadas e previamente autorizadas dentro do contexto e do processo que estão sendo compartilhadas e utilizadas. Em cas
# Title -> Índice
# UncategorizedText -> Relatório da administração ........................................................................................................................................... 1 Resumo do relatório do Comitê d
# Title -> RELATÓRIO DA ADMINISTRAÇÃO
# NarrativeText -> A Administração do Banco Bmg S.A. e de suas Controladas (“Banco”), em conformidade com as práticas contábeis adotadas no Brasil, estabelecidas pela Lei das Sociedades por Ações e pelo Banco Central do
# Title -> Banco Bmg
# NarrativeText -> O maior compromisso do Banco Bmg ao longo de seus quase 100 anos de história sempre foi com as pessoas e suas necessidades. Por isso, trabalhamos para manter nosso banco atual, tecnológico, ágil e sob
# NarrativeText -> Atendendo a milhões de clientes por todo o Brasil, o Bmg dispõe de um portfólio de soluções financeiras que abrange diversos públicos. Atuamos desde o mercado consignado, sendo nosso principal foco os
# NarrativeText -> Acreditamos que para sermos presentes na vida dos nossos clientes precisamos estar prontos para ajudar sempre que ele precisar, independente do canal ou forma de relacionamento: como, quando e onde el
# NarrativeText -> Em nossas principais verticais de atuação temos: Varejo, Atacado e Seguridade. Estamos evoluindo para um Banco melhor, mais forte e mais rentável com o objetivo de crescer e gerar resultados sustentáv
# Title -> Desempenho Financeiro
# NarrativeText -> Importante ressaltar que, desde o primeiro trimestre de 2025 os resultados do Banco estão sendo apresentados dentro de novos padrões normativos, principalmente em relação a Resolução CMN nº 4.966/21,
# NarrativeText -> A margem financeira totalizou R$ 2.892 milhões no primeiro semestre findo em 30 de junho de 2025, representando um aumento de 10,2% na comparação com o mesmo período do ano anterior. No 2T25, a margem
# Title -> Margem Financeira (R$ milhões)
# UncategorizedText -> 2.624
# UncategorizedText -> 2.892
# UncategorizedText -> 1.317
# UncategorizedText -> 1.416
# UncategorizedText -> 1.429
# UncategorizedText -> 1.449
# UncategorizedText -> 1.443
# UncategorizedText -> 746 2T24
# UncategorizedText -> 813 3T24
# UncategorizedText -> 815 4T24
# UncategorizedText -> 774 1T25
# UncategorizedText -> 891 2T25
# UncategorizedText -> 1.460
# UncategorizedText -> 1S24
# UncategorizedText -> 1.665
# UncategorizedText -> 1S25
# Title -> Margem financeira líquida
# UncategorizedText -> 1
# Title -> Margem financeira após o custo de crédito
# UncategorizedText -> 2
# UncategorizedText -> 1 – com base na DRE Gerencial, inclui receita de operações de crédito + receita de TVM + despesas de captação e derivativos + receita de prestação de serviços + operações de seguros.
# Footer -> 2 - margem financeira líquida + despesa de provisão líquida + despesa de comissão.
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 1 de 67
# NarrativeText -> No primeiro semestre findo em 30 de junho de 2025, o índice de eficiência foi de 50,8%, melhora de 3,2 p.p. em relação ao mesmo período de 2024. No 2T25, o índice atingiu 53,9%, aumento de 6,0 p.p. em
# Title -> Índice de Eficiência Operacional (%)
# UncategorizedText -> 54,3% 51,8% 51,4% 47,9% 53,9%
# UncategorizedText -> 54,0% 50,8%
# UncategorizedText -> 2T24
# UncategorizedText -> 3T24
# UncategorizedText -> 4T24
# UncategorizedText -> 1T25
# UncategorizedText -> 2T25
# UncategorizedText -> 1S24
# UncategorizedText -> 1S25
# UncategorizedText -> Metodologia de cálculo: (Despesas de Pessoal + Outras Despesas Administrativas (não considera amortização do ágio) + Outras Despesas Operacionais Líquidas de Receitas) / (Resultado da Intermediação fi
# NarrativeText -> O Lucro Líquido no primeiro semestre findo em 30 de junho de 2025 foi de R$ 240 milhões, aumento de 19,4% quando comparado a igual período de 2024. No 2T25, o lucro líquido foi de R$ 125 milhões, aume
# Title -> Lucro Líquido & ROAE R$ Milhões / % a.a.
# Title -> Lucro Líquido & ROAE Recorrentes R$ Milhões / % a.a.
# UncategorizedText -> 11,0%11,9% 9,6% 12,1%14,3%
# UncategorizedText -> 10,3%12,7%
# UncategorizedText -> 10,8%11,6%12,2%12,1%14,3%
# UncategorizedText -> 10,2%12,7%
# UncategorizedText -> 201 240
# UncategorizedText -> 200 240
# UncategorizedText -> 107 119
# UncategorizedText -> 99
# UncategorizedText -> 115 125
# UncategorizedText -> 105 116 125 115 125
# UncategorizedText -> 2T24 3T24 4T24 1T25 2T25
# UncategorizedText -> 1S24 1S25
# UncategorizedText -> 2T24 3T24 4T24 1T25 2T25
# UncategorizedText -> 1S24 1S25
# Title -> Lucro Líquido
# Title -> ROAE
# Title -> Lucro Líquido Recorrente
# Title -> ROAE Recorrente
# NarrativeText -> O Patrimônio Líquido consolidado em 30 de junho de 2025 atingiu o valor de R$ 3.731 milhões e o índice de capitalização ponderado pelo risco dos ativos (Índice de Basileia) correspondeu a 12,7%.
# NarrativeText -> No primeiro semestre findo em 30 de junho de 2025, o Banco provisionou R$ 121,9 milhões de Juros sobre o Capital Próprio, dos quais R$ 58,3 milhões foram declarados referentes ao segundo trimestre de
# NarrativeText -> Concomitante ao pagamento de JCP, o Banco anunciou em 15 de julho de 2025, aumento de capital que será de no mínimo R$ 35,4 milhões e no máximo R$ 49,5 milhões.
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 2 de 67
# Title -> Patrimônio Líquido & Índice de Basileia R$ Milhões / %
# UncategorizedText -> 13,9%
# UncategorizedText -> 14,0%
# UncategorizedText -> 13,2%
# UncategorizedText -> 12,2%
# UncategorizedText -> 12,7%
# UncategorizedText -> 4.120
# UncategorizedText -> 4.258
# UncategorizedText -> 4.306
# UncategorizedText -> 3.648
# UncategorizedText -> 3.731
# UncategorizedText -> 2T24
# UncategorizedText -> 3T24
# UncategorizedText -> 4T24
# UncategorizedText -> 1T25
# UncategorizedText -> 2T25
# Title -> Patrimônio Líquido
# Title -> Índice de Basileia
# NarrativeText -> A carteira total de operações de crédito encerrou 30 de junho de 2025 com saldo de R$ 24.680 milhões, representando um aumento de 1,7% em doze meses e redução de 8,0% em relação ao primeiro trimestre
# Title -> Carteira de Crédito R$ Milhões
# UncategorizedText -> 24.276 25.210 26.336 26.817 24.680
# Title -> Distribuição da Carteira (%)
# Title -> Varejo PF 11,0%
# Title -> Atacado 9,5%
# Title -> Produtos Consignados 70,1%
# Title -> Consignado nos EUA 9,4%
# UncategorizedText -> 2T24
# UncategorizedText -> 3T24
# UncategorizedText -> 4T24
# UncategorizedText -> 1T25
# UncategorizedText -> 2T25
# NarrativeText -> A captação total consolidada encerrou o 30 de junho de 2025 com saldo de R$ 35.748 milhões, representando uma redução de 0,4% em relação ao mesmo período do ano anterior e aumento de 6,9% em relação a
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 3 de 67
# UncategorizedText -> 35.909
# UncategorizedText -> 34.318
# Title -> Captação R$ Milhões
# UncategorizedText -> 32.922 33.450 35.748
# Title -> Estrutura de captação com o mercado (%)
# Title -> Cessões e Securitização 17,8%
# Title -> Outros 4,9%
# Title -> Letras Financeiras 10,4%
# Title -> Depósito a Prazo 66,9%
# UncategorizedText -> 2T24
# UncategorizedText -> 3T24
# UncategorizedText -> 4T24
# UncategorizedText -> 1T25
# UncategorizedText -> 2T25
# NarrativeText -> Em 30 de junho de 2025, os investimentos do Banco em controladas totalizaram R$ 136 milhões, sendo a principal variação no trimestre o resultado de equivalência patrimonial e provisionamento para dist
# Title -> Princípios ASG
# NarrativeText -> No Banco Bmg, a sustentabilidade dos nossos negócios está ligada à agenda ASG: nossa responsabilidade com o meio Ambiente, a geração de impacto Social positivo e uma Governança ética e transparente. É
# NarrativeText -> Reforçando nosso posicionamento como empresa, fomos o primeiro banco brasileiro a receber a certificação internacional concedida pelo Age Friendly Institute, representado no Brasil pela Maturi, que re
# NarrativeText -> Também somos uma das empresas mantenedoras do Instituto Marina e Flávio Guimarães (IMFG), que centraliza as ações sociais do Grupo Bmg. Fundado para impulsionar transformações sociais, o IMFG promove
# UncategorizedText -> O Bmg é signatário de movimentos importantes como Pacto Global da ONU, Pacto de Promoção pela Equidade Racial, Rede Empresarial de Inclusão Social, Movimento Mulher 360, Women on Board (WOB), Fórum de
# NarrativeText -> Publicamos pelo segundo ano consecutivo nosso Relatório Anual de Sustentabilidade (2024) e o 2º Inventário de Emissões de Gases de Efeito Estufa (GEE), em conformidade com o GHG Protocol e com a neutr
# Title -> Saiba mais sobre nossas https://www.bancobmg.com.br/compromisso-ASG/.
# NarrativeText -> iniciativas ASG no nosso Relatório Anual de Sustentabilidade e no site:
# Title -> Governança Corporativa
# NarrativeText -> O Banco possui uma estrutura robusta de governança corporativa. Além das obrigações estabelecidas no Nível 1 de governança corporativa da B3 S.A – Brasil, Bolsa, Balcão, o Banco adotou por boas prátic
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 4 de 67
# NarrativeText -> O Banco tem desenvolvido, com base nas melhores práticas de gerenciamento de riscos, políticas, sistemas e controles internos para a mitigação e controle de possíveis perdas decorrentes da exposição a
# NarrativeText -> Para maiores informações sobre governança corporativa acesse: www.bancobmg.com.br/ri.
# Title -> Relacionamento com os Auditores Independentes
# NarrativeText -> A política adotada atende aos princípios que preservam a independência do auditor, de acordo com os critérios internacionalmente aceitos, quais sejam, o auditor não deve auditar o seu próprio trabalho
# Title -> Gestão de Capital
# NarrativeText -> A avaliação da suficiência de capital é realizada de forma contínua para assegurar que o Banco mantenha uma sólida base de capital para apoiar o desenvolvimento das suas atividades. Considera ainda um
# Title -> Agradecimentos
# NarrativeText -> Todas essas realizações refletem o firme propósito dos Acionistas e da Administração na busca contínua para superar expectativas e oferecer sempre um serviço de alta qualidade aos seus clientes e um a
# NarrativeText -> São avanços que se concretizam graças ao apoio e à confiança dos nossos clientes e ao trabalho dedicado do quadro de colaboradores e parceiros/correspondentes.
# NarrativeText -> A todos eles, nossos agradecimentos.
# Title -> À ADMINISTRAÇÃO
# Title -> São Paulo, 14 de agosto de 2025.
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 5 de 67
# Title -> RESUMO DO RELATÓRIO DO COMITÊ DE AUDITORIA DO BANCO BMG
# Title -> Primeiro semestre de 2025
# NarrativeText -> O Comitê de Auditoria, na forma da Resolução 4.910/21, editada pelo Banco Central do Brasil, e do seu regimento interno, tem como competência zelar pela integridade e qualidade das demonstrações finan
# Title -> Atividades Exercidas no Período:
# NarrativeText -> O Comitê de Auditoria realizou, no primeiro semestre de 2025, 07 (sete) reuniões. Adicionalmente, foram realizadas 03 (três) reuniões neste segundo semestre de 2025 para avaliação final das demonstraç
# NarrativeText -> Sistemas de controles internos e de Gerenciamento de Riscos:
# NarrativeText -> No primeiro semestre de 2025 o BMG continuou aprimorando e atualizando as suas normas e procedimentos e fortalecendo do processo de Governança Corporativa. O Comitê acompanhou os trabalhos das áreas c
# Title -> Auditoria Interna:
# NarrativeText -> O Comitê de Auditoria, além de discutir e aprovar a formulação dos planos de trabalho da área, recebeu todos os relatórios dos trabalhos realizados, com monitoramento da implementação de planos de açã
# Title -> Auditoria Externa:
# NarrativeText -> A PricewaterhouseCoopers Auditores Independentes é a empresa responsável pela auditoria externa das demonstrações financeiras do Conglomerado Financeiro BMG, devendo certificar que elas representem de
# Title -> Demonstrações Financeiras:
# NarrativeText -> O Comitê de Auditoria analisou os aspectos que envolvem o processo de elaboração das Demonstrações Financeiras, Notas Explicativas, Relatórios Financeiros e Relatório da Administração, com data-base d
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 6 de 67
# Title -> Conclusões:
# NarrativeText -> O Comitê de Auditoria não recebeu, até a presente data, registro de qualquer denúncia de descumprimento de normas, ausência de controles, ato ou omissão por parte da Administração da Instituição que i
# NarrativeText -> Com base nas considerações acima, o Comitê de Auditoria, ponderadas devidamente as suas responsabilidades e as limitações naturais decorrentes do escopo da sua atuação, recomenda ao Conselho de Admini
# Title -> São Paulo, 14 de agosto de 2025
# Title -> Dorival Dourado Jr
# Title -> José Eduardo Gouveia Dominicale
# Title -> Marco Antonio Antunes (Presidente e Membro Especialista)
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 7 de 67
# Title -> PARECER DO CONSELHO FISCAL
# NarrativeText -> No exercício de suas atribuições legais e estatutárias, os membros do Conselho Fiscal do Banco Bmg S.A., após exame do Relatório da Administração e das Demonstrações Financeiras individuais e consolid
# Title -> São Paulo, 14 de agosto de 2025
# Title -> Roberto Faldini Conselheiro Coordenador
# Title -> Fernando Antônio Fraga Ferreira Conselheiro
# Title -> Luciano Luiz Barsi Conselheiro
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 8 de 67
# UncategorizedText -> BANCO BMG S.A. (BANCO) E BANCO BMG S.A E SUAS CONTROLADAS (CONSOLIDADO) BALANÇO PATRIMONIAL EM 30 DE JUNHO DE 2025 Em milhares de reais
# NarrativeText -> ConsolidadoBancoNota20252025AtivoDisponibilidades4517.695 50.667 Instrumentos Financeiros537.162.524 34.508.340 Aplicações interfinanceiras de liquidez5.143.347 2.132.974 Títulos e valores mobiliários
# UncategorizedText -> As notas explicativas da administração são parte integrante das Demonstrações Financeiras individuais e consolidadas.
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 9 de 67
# UncategorizedText -> BANCO BMG S.A. (BANCO) E BANCO BMG S.A E SUAS CONTROLADAS (CONSOLIDADO) BALANÇO PATRIMONIAL EM 30 DE JUNHO DE 2025 Em milhares de reais
# NarrativeText -> ConsolidadoBancoNota20252025Passivo e Patrimônio LíquidoDepósitos e demais instrumentos financeiros10 34.319.016 35.713.269 Depósitos10.125.581.091 27.149.113 Captações no mercado aberto - carteira pr
# UncategorizedText -> As notas explicativas da administração são parte integrante das Demonstrações Financeiras individuais e consolidadas.
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 10 de 67
# UncategorizedText -> BANCO BMG S.A. (BANCO) E BANCO BMG S.A E SUAS CONTROLADAS (CONSOLIDADO) DEMONSTRAÇÃO DO RESULTADO SEMESTRE FINDO EM 30 DE JUNHO Em milhares de reais, exceto quando indicado de outra forma
# NarrativeText -> ConsolidadoBancoNota20252025Receitas da intermediação financeira4.692.877 4.487.778 Operações de crédito14(a)3.284.651 3.201.612 Resultado de operações com títulos e valores mobiliários14(b)1.408.226
# UncategorizedText -> As notas explicativas da administração são parte integrante das Demonstrações Financeiras individuais e consolidadas.
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 11 de 67
# UncategorizedText -> BANCO BMG S.A. (BANCO) E BANCO BMG S.A E SUAS CONTROLADAS (CONSOLIDADO) DEMONSTRAÇÃO DO RESULTADO ABRANGENTE SEMESTRE FINDO EM 3O DE JUNHO Em milhares de reais
# NarrativeText -> Consolidado e Banco2025Lucro líquido do semestre240.127Outros resultados abrangentes Itens que serão reclassificados para o resultado Títulos disponíveis para venda – Próprios60.267 Títulos disponívei
# UncategorizedText -> As notas explicativas da administração são parte integrante das Demonstrações Financeiras individuais e consolidadas.
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 12 de 67
# UncategorizedText -> BANCO BMG S.A. (BANCO) E BANCO BMG S.A E SUAS CONTROLADAS (CONSOLIDADO) DEMONSTRAÇÃO DAS MUTAÇÕES NO PATRIMÔNIO LÍQUIDO EM 30 DE JUNHO Em milhares de reais
# NarrativeText -> LegalEstatutáriaOutrasSaldos em 31 de dezembro de 20243.742.571 14.070 169.826 458.817 5.894 (74.439) (11.101) - 4.305.638 173.533 4.479.171 Efeito da adoção inicial da Resolução 4.966/21- - - (694.18
# UncategorizedText -> As notas explicativas da administração são parte integrante das Demonstrações Financeiras individuais e consolidadas.
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 13 de 67
# UncategorizedText -> BANCO BMG S.A. (BANCO) E BANCO BMG S.A E SUAS CONTROLADAS (CONSOLIDADO) DEMONSTRAÇÃO DOS FLUXOS DE CAIXA SEMESTRE FINDO EM 30 DE JUNHO Em milhares de reais
# NarrativeText -> ConsolidadoBanco20252025Fluxos de caixa das atividades operacionaisLucro líquido do semestre240.127 240.127 Ajuste ao Lucro líquido 687.733 373.221 Reconhecimento de planos de pagamento baseado em açõ
# UncategorizedText -> As notas explicativas da administração são parte integrante das Demonstrações Financeiras individuais e consolidadas.
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 14 de 67
# UncategorizedText -> BANCO BMG S.A. (BANCO) E BANCO BMG S.A E SUAS CONTROLADAS (CONSOLIDADO) DEMONSTRAÇÃO DO VALOR ADICIONADO SEMESTRE FINDO EM 30 DE JUNHO Em milhares de reais
# NarrativeText -> ConsolidadoBanco202520251 – Receitas4.424.108 4.423.130 Intermediação financeira4.692.877 4.487.778 Prestação de serviços133.245 65.639 Provisão para créditos de liquidação duvidosa(876.257) (485.000)
# UncategorizedText -> As notas explicativas da administração são parte integrante das Demonstrações Financeiras individuais e consolidadas.
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 15 de 67
# UncategorizedText -> BANCO BMG S.A. (BANCO) E BANCO BMG S.A E SUAS CONTROLADAS (CONSOLIDADO) NOTAS EXPLICATIVAS DA ADMINISTRAÇÃO ÀS DEMONSTRAÇÕES FINANCEIRAS INDIVIDUAIS E CONSOLIDADAS EM 30 DE JUNHO DE 2025 Em milhares d
# UncategorizedText -> 1.
# Title -> Contexto operacional
# NarrativeText -> As operações do Banco Bmg S.A (“Bmg” ou “Banco”) são conduzidas no contexto de um conjunto de instituições que atuam integradamente no mercado financeiro, sendo que certas operações têm a coparticipaç
# NarrativeText -> O Banco Bmg S.A, constituído sob a forma de Companhia Aberta, controlado pela Família Pentagna Guimarães está situado na Avenida Presidente Juscelino Kubitscheck, nº 1.830, São Paulo/SP, Brasil., poss
# NarrativeText -> Conforme AGE realizada em 03 de junho de 2024, e, após aprovação pelo Banco Central do Brasil, através de publicação no Diário Oficial em 29 de julho de 2024, comunicamos a alteração na denominação so
# NarrativeText -> Conforme AGE realizada em 07 de fevereiro de 2025, aprovado pelo Banco Central do Brasil, comunicamos a alteração na denominação social da Banco Cifra S.A. para Banco BMG Soluções Financeiras S.A..
# NarrativeText -> Conforme Resolução BCB nº 2/20 as Demonstrações Financeiras incluem as demonstrações financeiras individuais, bem com as demonstrações financeiras consolidadas (nota 2.2 t), conforme segue:
# Title -> Participação em %
# Title -> Controladas
# NarrativeText -> Araújo Fontes Investimentos Ltda. BMG Leasing S.A. BMG Bank Cayman Ltd. Banco BMG Consignado S.A. Banco BMG Soluções Financeiras S.A. BMG S.A. Distribuidora de Títulos e Valores Mobiliários CBFácil Co
# Title -> País de constituição Brasil Brasil
# Title -> Atividade
# Title -> Investimentos Arrendamento Mercantil
# UncategorizedText -> Ilhas Cayman Banco Banco Banco Distribuidora de valores mobiliários Intermediação de negócios Intermediação de negócios Intermediação de negócios Comércio eletrônico Holding Seguros Holding Seguros
# Title -> Brasil Brasil Brasil Brasil Brasil Brasil Brasil Brasil Brasil Brasil Brasil
# UncategorizedText -> 2025
# UncategorizedText -> 50 99,99 100 100 100 100 99,99 99,98 80 99,38 99,99 100 100 60
# NarrativeText -> Em dezembro de 2018, o Banco obteve o registro na Comissão de Valores Mobiliários de companhia aberta.
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 16 de 67
# UncategorizedText -> BANCO BMG S.A. (BANCO) E BANCO BMG S.A E SUAS CONTROLADAS (CONSOLIDADO) NOTAS EXPLICATIVAS DA ADMINISTRAÇÃO ÀS DEMONSTRAÇÕES FINANCEIRAS INDIVIDUAIS E CONSOLIDADAS EM 30 DE JUNHO DE 2025 Em milhares d
# UncategorizedText -> 2.
# NarrativeText -> Apresentação das Demonstrações Financeiras e principais práticas contábeis
# UncategorizedText -> 2.1.
# NarrativeText -> Apresentação das Demonstrações Financeiras individuais e consolidadas
# NarrativeText -> As Demonstrações Financeiras foram elaboradas de acordo com as práticas contábeis adotadas no Brasil, aplicáveis as instituições autorizadas a funcionar pelo Banco Central do Brasil (BACEN), e diretri
# NarrativeText -> Em março de 2024, visando apresentar as informações contábeis de forma mais ampla, o Banco passou a divulgar as demonstrações financeiras consolidadas e suas respectivas notas explicativas, incluindo
# NarrativeText -> As Demonstrações Financeiras foram concluídas e aprovadas pelo Conselho de Administração do Banco em 14 de agosto de 2025.
# NarrativeText -> O Comitê de Pronunciamentos Contábeis – CPC emitiu pronunciamentos relacionados ao processo de convergência contábil internacional. Desta forma, o Consolidado, na elaboração das demonstrações financei
# UncategorizedText -> Resolução CMN nº 4.924/21 – CPC 00 (R2) - Pronunciamento Conceitual Básico, CPC 01 (R1) - Redução ao Valor Recuperável de Ativos, CPC 23 - Políticas Contábeis, Mudança de Estimativa e Retificação de E
# UncategorizedText -> Resolução CMN nº 3.989/11 – CPC 10 (R1) - Pagamento Baseado em Ações.
# UncategorizedText -> Resolução CMN nº 3.823/09 – CPC 25 - Provisões, Passivos Contingentes e Ativos Contingentes.
# UncategorizedText -> Resolução CMN nº 4.924/21 – CPC 46 (R1) - Mensuração do Valor Justo.
# UncategorizedText -> Resolução CMN nº 4.818/20 – CPC 03 (R2) - Demonstração dos Fluxos de Caixa, CPC 05 (R1) - Divulgação sobre Partes Relacionadas, CPC 24 - Evento Subsequente e CPC 41 (R1) – Resultado por Ação.
# UncategorizedText -> Resolução CMN n° 4.967/21 - Pronunciamento Técnico CPC 28 – Propriedade para Investimento.
# UncategorizedText -> Resolução CMN nº 4.877/20 - Pronunciamento Técnico CPC 33 (R1) – Benefícios a Empregados.
# NarrativeText -> Alguns números inclusos neste Relatório foram submetidos a ajustes de arredondamento. Assim sendo, os valores indicados como totais em alguns quadros podem não ser a soma aritmética dos números que os
# UncategorizedText -> 2.2.
# NarrativeText -> Resoluções adotadas a partir de 01 de janeiro de 2025
# Title -> 2.2.1. Resolução CMN nº 4.966, de 25 de novembro de 2021
# NarrativeText -> Em 25 de novembro de 2021, o Conselho Monetário Nacional publicou a Resolução CMN nº 4.966, com vigência a partir de 1° de janeiro de 2025. Esta resolução dispõe sobre os critérios contábeis aplicávei
# NarrativeText -> No contexto dessa resolução, foram emitidas outras normativas complementares. A Resolução BCB nº 352/23 estabelece parâmetros e pisos de provisionamento, além de esclarecer aspectos relacionados à tax
# Footer -> Banco Bmg S.A. e suas Controladas - Relatório das Demonstrações Financeiras Página 17 de 67
# UncategorizedText -> BANCO BMG S.A. (BANCO) E BANCO BMG S.A E SUAS CONTROLADAS (CONSOLIDADO) NOTAS EXPLICATIVAS DA ADMINISTRAÇÃO ÀS DEMONSTRAÇÕES FINANCEIRAS INDIVIDUAIS E CONSOLIDADAS EM 30 DE JUNHO DE 2025 Em milhares d
# NarrativeText -> Com a implementação das novas regras, várias normativas atuais foram revogadas, como as Circulares nº 3.068/01 e nº 3.082/02, que tratavam, respectivamente, da contabilização de títulos e valores mobi

# %%
print(f"Total de elementos extraídos: {len(elementos)}")

tipos = set(e.category for e in elementos)
print("Categorias encontradas:", tipos)
# Out:
# Total de elementos extraídos: 1126
# Categorias encontradas: {'ListItem', 'UncategorizedText', 'NarrativeText', 'Title', 'Footer'}

# %%
# Filtra apenas os elementos do tipo ListItem
list_items = [e for e in elementos if e.category == "ListItem"]

print(f"Total de ListItem encontrados: {len(list_items)}")

# Pega os 5 primeiros
for i, e in enumerate(list_items[:5], 1):
    print(f"\n--- ListItem {i} ---")
    print(str(e))
# Out:
# Total de ListItem encontrados: 34
#
# --- ListItem 1 ---
# Mantidos para coleta dos fluxos de caixa contratuais • Mantidos para coleta dos fluxos de caixa contratuais e venda • Mantidos para negociação/outros
#
# --- ListItem 2 ---
# Ativos administrados tanto para obter fluxos de caixa constituídos apenas de pagamentos de principal e juros (Teste SPPJ), quanto para a venda;
#
# --- ListItem 3 ---
# Estes ativos são inicialmente e subsequentemente reconhecidos a valor justo mais custos de transação; e
#
# --- ListItem 4 ---
# Os ganhos e perdas não realizados (exceto perda de crédito esperada, diferenças cambiais, dividendos e receita de juros) são reconhecidos, líquidos dos impostos aplicáveis, na rubrica Resultado Abrangente Acumulado.
#
# --- ListItem 5 ---
# Ativos que não atendem os critérios de classificação das categorias anteriores; ou ativos designados no reconhecimento inicial como ao valor justo por meio do resultado para reduzir “descasamentos contábeis”;

# %% [markdown]
# ### Vetorizando a base de dados

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Pegar só o texto limpo
docs = [str(e) for e in elementos if str(e).strip() != ""]

print(f"Total de blocos extraídos: {len(docs)}")
print(docs[0][:300])  # exemplo do primeiro

# Criando Chunks 

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=2000,   # até 1000 caracteres por chunk
    chunk_overlap=100  # sobreposição para manter contexto
)

chunks = text_splitter.split_text("\n".join(docs))

print(f"Total de chunks: {len(chunks)}")
print(chunks[0][:300])
# Out:
# Total de blocos extraídos: 1122
# BMGB B3 LISTED N1
# Total de chunks: 122
# BMGB B3 LISTED N1
# Demonstrações financeiras individuais e consolidadas em 30 de junho de 2025 e relatório do auditor independente sobre as demonstrações financeiras
# Este documento contém informação RESTRITA. Seu conteúdo é restrito às partes interessadas e previamente autorizadas dentro do contexto

# %% [markdown]
# ### Criando embeddings

# %%
import pinecone
print(pinecone.__file__)
# Out:
# c:\Users\Matheus Almeida\OneDrive\Documentos\Insper\Estágio\market_sizing\venv\Lib\site-packages\pinecone\__init__.py

# %%
# Pinecone (SDK novo usa import do módulo inteiro)
from pinecone import Pinecone, ServerlessSpec
pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))


# LangChain + Pinecone + OpenAI
from langchain_pinecone import PineconeVectorStore
from langchain_openai import OpenAIEmbeddings
from langchain_community.document_loaders import DirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Inicializa o cliente
load_dotenv()

openai_key = os.getenv("OPENAI_API_KEY")
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))

# Cria o índice (só precisa fazer 1 vez, se não existir ainda)
index_name = "meu-indice"

if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=1536,  # precisa bater com a dimensão do embedding
        metric="cosine",
        spec=ServerlessSpec(cloud="aws", region="us-east-1")
    )

# Conecta ao índice
index = pc.Index(index_name)

# Carrega os chunks para o Pinecone
vectorstore = PineconeVectorStore.from_texts(
    texts=chunks,
    embedding=embeddings,
    index_name=index_name
)

print("Base vetorial criada no Pinecone com sucesso!")
# Out:
# Base vetorial criada no Pinecone com sucesso!

# %%
query = "Qual o valor da Provisão para Créditos de Liquidação Duvidosa do ano de 2024?"
resultados = vectorstore.similarity_search(query, k=3)

for r in resultados:
    print("\n--- Trecho encontrado ---")
    print(r.page_content)
# Out:
# --- Trecho encontrado ---
# Os créditos tributários relacionados as adições temporárias referem-se, principalmente, a Provisões para causas fiscais e previdenciárias discutidos em âmbito judicial ou administrativo, provisões trabalhistas e cíveis, cuja realização depende do encerramento dos respectivos processos, e provisão para crédito de liquidação duvidosa cuja realização depende dos critérios de dedutibilidade nos termos da Lei nº 14.467/2022.
# Os estudos técnicos elaborados em junho de 2025 demonstram a capacidade da Instituição de geração de lucros tributáveis suficientes para compensar os créditos tributários existentes.
# (b) demonstrada como segue:
# Expectativa de realização dos créditos tributários no semestre findo em 30 de junho de 2025 pode ser
# AnoConsolidadoBanco2025 420.497 401.230 2026 522.267 465.112 2027 597.843 482.394 2028 457.768 403.085 2029 512.455 455.444 Após 2029 2.425.843 2.340.250 Total 4.936.673 4.547.515
# (c)
# Obrigações fiscais diferidas - imposto de renda e contribuição social
#
# --- Trecho encontrado ---
# (i) Provisão para riscos fiscais - Equivalem ao valor principal dos tributos envolvidos em discussões fiscais administrativas ou judiciais, objeto de autolançamento ou lançamento de ofício, acrescido de juros e, quando aplicável, multa e encargos. Tal valor é objeto de provisão contábil, independentemente da probabilidade de perda, quando se trata de obrigação legal, ou seja, o êxito na ação depende de ser reconhecida a inconstitucionalidade de lei vigente. Nos demais casos constituem provisão sempre que a perda for provável.
# Os processos contingentes de ações fiscais e tributárias avaliados como risco de perda possível não são reconhecidos contabilmente, cujo risco total estimado é de R$1.928.950 no Consolidado e R$1.751.319 no Banco, sendo que estas ações se referem principalmente a processos judiciais de tributos federais.
# Os principais questionamentos no Consolidado são:
# a) contribuição social sobre despesas alegadamente indedutíveis;
#
# --- Trecho encontrado ---
# ConsolidadoBanco20252025Saldo no início do período 1.131.975 760.099 Efeito da adoção inicial da Resolução 4.966/21 1.261.311 579.263 Saldo em 01/01/2025 2.393.286 1.339.362 Constituição de provisão 876.257 485.000 (Reversão/baixa) de provisão (1.299.190) (391.504)Saldo no fim do período 1.970.353 1.432.858 Créditos recuperados (143.561) (116.459)Efeito no resultado (i) 732.696 368.541
# (i)
# Refere-se ao valor líquido de constituição de provisão e créditos recuperados.
# (f)
# Composição da carteira e provisão constituída para perdas associadas ao risco de crédito por estágios
# i. Resumo
